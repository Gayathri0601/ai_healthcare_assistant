# %%
# !pip install openai

# %%
from google.colab import userdata
import os
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_Key')

# %%
from openai import OpenAI
client = OpenAI()

symptoms = input("Enter your symptoms: ")

prompt = f"""
You are an AI healthcare assistant.

Based on the symptoms provided, generate a structured response in the following format:

1. Possible Conditions (2-3 conditions)
2. Severity Level (Low / Medium / High)
3. Recommended Actions
4. When to See a Doctor

Keep the explanation simple and easy to understand.

Symptoms: {symptoms}

IMPORTANT:
- Do not provide exact medical diagnosis
- Add disclaimer: "This is not medical advice"
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}]
)


result = response.choices[0].message.content

print("\n==============================")
print(" AI HEALTHCARE ASSISTANT ")
print("==============================\n")

print(result)

print("\n==============================")
# Out:
# Enter your symptoms: dandruff and hairfall
#
# ...
#  AI HEALTHCARE ASSISTANT
# ...
#
# 1. **Possible Conditions**
#    - Seborrheic dermatitis (a common skin condition causing dandruff)
#    - Stress or hormonal changes affecting hair health
#    - Nutritional deficiencies (such as lack of vitamins and minerals)
#
# 2. **Severity Level**
#    - **Medium**: While dandruff and hair fall can be common, they can also indicate an underlying issue that may need attention.
#
# 3. **Recommended Actions**
#    - Use an anti-dandruff shampoo regularly.
#    - Maintain a healthy diet rich in vitamins and minerals (like B vitamins, zinc, and omega-3 fatty acids).
#    - Manage stress through relaxation techniques like meditation or yoga.
#
# 4. **When to See a Doctor**
#    - If the dandruff persists despite using over-the-counter shampoos.
#    - If hair fall increases significantly or you notice bald patches.
#    - If you experience itching, redness, or swelling on the scalp.
#
# ...
